# %% [markdown]
# # Leval 1 : Task 1 : Data Exploration and Preprocessing

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Imprting dataset.

# %%
data = pd.read_csv("Dataset .csv")

# %%
data.head()  #Top five row.
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.tail()  # last five row
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data.shape    #identify the number of rows and columns. rows = 9551 , columns = 21
# Out:
# (9551, 21)

# %%
# Checking missing values.

data.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
print(data.isnull().sum().value_counts())  # in one row 9 missing values.
# Out:
# 0    20
# 9     1
# dtype: int64

# %%
# filling missing values by mode of that perticular column.

data['Cuisines'].fillna(data['Cuisines'].mode()[0], inplace=True)

# %%
print(data.isnull().sum())  # now the all missing values are filled.
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Perform data type conversion if necessary.

print(data.dtypes)

# No need of data type conversion.
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# # Level 1 -> Task 2:Descriptive Analysis

# %%
# Calculating the basic statistical measures (mean,
# median, standard deviation, etc.) for numerical
# columns.

data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# calculating mean for all numeric column

print(data.mean())
# Out:
# Restaurant ID           9.051128e+06
# Country Code            1.836562e+01
# Longitude               6.412657e+01
# Latitude                2.585438e+01
# Average Cost for two    1.199211e+03
# Price range             1.804837e+00
# Aggregate rating        2.666370e+00
# Votes                   1.569097e+02
# dtype: float64
# C:\Users\vc964\AppData\Local\Temp\ipykernel_18724\3002551319.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.mean())

# %%
# calculating median for all numeric column

print(data.median())
# Out:
# Restaurant ID           6.004089e+06
# Country Code            1.000000e+00
# Longitude               7.719196e+01
# Latitude                2.857047e+01
# Average Cost for two    4.000000e+02
# Price range             2.000000e+00
# Aggregate rating        3.200000e+00
# Votes                   3.100000e+01
# dtype: float64
# C:\Users\vc964\AppData\Local\Temp\ipykernel_18724\74828377.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.median())

# %%
# calculating standard deviation for all numeric column

print(data.std())
# Out:
# Restaurant ID           8.791521e+06
# Country Code            5.675055e+01
# Longitude               4.146706e+01
# Latitude                1.100794e+01
# Average Cost for two    1.612118e+04
# Price range             9.056088e-01
# Aggregate rating        1.516378e+00
# Votes                   4.301691e+02
# dtype: float64
# C:\Users\vc964\AppData\Local\Temp\ipykernel_18724\28645378.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.std())

# %%
# calculating variance for all numeric column

print(data.var())
# Out:
# Restaurant ID           7.729085e+13
# Country Code            3.220624e+03
# Longitude               1.719517e+03
# Latitude                1.211746e+02
# Average Cost for two    2.598925e+08
# Price range             8.201274e-01
# Aggregate rating        2.299401e+00
# Votes                   1.850455e+05
# dtype: float64
# C:\Users\vc964\AppData\Local\Temp\ipykernel_18724\2248332847.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.var())

# %%
# calculating min for all numeric column.

print(data.min())
# Out:
# Restaurant ID                                                          53
# Restaurant Name                                                       #45
# Country Code                                                            1
# City                                                            Abu Dhabi
# Address                 1 & 2, Block A-5 B, DDA Market, Paschim Vihar,...
# Locality                                ILD Trade Centre Mall, Sohna Road
# Locality Verbose               ILD Trade Centre Mall, Sohna Road, Gurgaon
# Longitude                                                     -157.948486
# Latitude                                                       -41.330428
# Cuisines                                                          Afghani
# Average Cost for two                                                    0
# Currency                                                 Botswana Pula(P)
# Has Table booking                                                      No
# ...

# %%
# calculating max for all numeric column

print(data.max())
# Out:
# Restaurant ID                                                    18500652
# Restaurant Name                                         �ukura��a Sofras۱
# Country Code                                                          216
# City                                                            ��stanbul
# Address                 ��mitk�_y Mahallesi, 2432. Cadde (8. Cadde), N...
# Locality                                                        ��mitk�_y
# Locality Verbose                                        ��mitk�_y, Ankara
# Longitude                                                      174.832089
# Latitude                                                         55.97698
# Cuisines                                  World Cuisine, Patisserie, Cafe
# Average Cost for two                                               800000
# Currency                                                 Turkish Lira(TL)
# Has Table booking                                                     Yes
# ...

# %%
# Explore the distribution of categorical
# variables like "Country Code,
# " "City,
# " and
# "Cuisines.
# "

# Distribution of Country Code

country_code_distribution = data["Country Code"].value_counts()

# %%
print(country_code_distribution)
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
 data[data["Country Code"] ==162]
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
# Distribution of city 
city_distribution = data["City"].value_counts()

# %%
print(city_distribution)
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
Cuisines_distribution = data["Cuisines"].value_counts()

# %%
# Distribution of cuisines 
Cuisines_distribution
# Out:
# North Indian                                             945
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
data[data["Cuisines"]== "North Indian"]
# Out:
#       Restaurant ID                 Restaurant Name  Country Code  \
# 84         17284105                   Cookie Shoppe           216
# 87         17284211  Pearly's Famous Country Cookng           216
# 94         17284158               Jimmie's Hot Dogs           216
# 297        17374552                  Corkscrew Cafe           216
# 328        17501439                        Dovetail           216
# ...             ...                             ...           ...
# 9148       18378803                    #Dilliwaala6             1
# 9173       18441490                  Barbeque Ville             1
# 9227        3200002        Gazebo Garden Restaurant             1
# 9241        3900250                    Baati Chokha             1
# 9245        3900058        Chrystal Bowl Restaurant             1
#
#              City                                            Address  \
# 84         Albany                 115 N Jackson St, Albany, GA 31701
# ...

# %%
Top_cuisines = data["Cuisines"].value_counts().head(10) # Groups of cuisine and count the number of restaurants

# %%
print(Top_cuisines)
# Out:
# North Indian                      945
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
Top_citys = data["City"].value_counts().head(10)  # Groups of city and count the number of restaurants

# %%
Top_citys   # The highest number of restaurants in "New Delhi"
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: City, dtype: int64

# %% [markdown]
# # Level 1-> Task 3: Geospatial Analysis

# %% [markdown]
# Visualizing the locations of restaurants on a
# map using latitude and longitude
# information.

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initialize a map centered around a specific location (e.g., the average latitude and longitude)
import folium

center_latitude = data['Latitude'].mean()
center_longitude = data['Longitude'].mean()
restaurant_map = folium.Map(location=[center_latitude, center_longitude], zoom_start=12)

# %%
restaurant_map

# %%
# Add markers to the map
for index, row in data.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Restaurant Name'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(restaurant_map)

# Save the map to an HTML file
restaurant_map.save('restaurant_map.html')

# %%
restaurant_map
